# %% [markdown]
# <a href="https://colab.research.google.com/github/ksj-ops/DataStructure-Assignment5-Heap-/blob/main/20251177(assignment5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1번
# 1.  3개(7,17,70)
# 2. 8개
# 3. 1개 (차이)
# 4. 모두 성립됨

# %% [markdown]
# #2번
# 1. leaf_nodes= (n+1)//2
# 2. 전체 노드에서 리프노드의 수를 빼면 내부노드이다. 즉, (내부노드)+(리프노드)=(전체노드)

# %% [markdown]
# #3번
# 1. 5,3,1,8,7,6,9
# 2. 1,3,5,6,7,8,9
# 3. 1,3,6,7,9,8,5
# 4. <증명>
# 베이스 케이스: h=1일때 (h:height)
# T는 단 한 개의 노드를 갖는다.
# 유일한 노드를 방문하는 것은 당연히 정렬된 순서다.
#
# 귀납적 가정: h<k인 모든 k에 대해 중위순회가 정렬순서로 방문한다고 가정한다.
#
# 귀납적 전개: 전체 트리 T는 루트 r과 왼쪽 서브트리 TL, 오른쪽 서브트리 TR로 구성됩니다. 이때 TL,TR은 전체 트리 T보다 높이가 낮으므로(최대h-1) 가정에 의해 이미 정렬된 상태로 방문된다.
#
# TL의 값들<r의 값<TR의 값
# 따라서, [작은 값들의 정렬된 묶음]-> [중간값 r]-> [큰 값들의 정렬된 묶음] 순서가 되므로, 전체 트리 T도 정렬된 순서로 방문됩니다.

# %% [markdown]
# #4번
# 55부터 시작한다
# 1) 30<55 -> 왼쪽으로 이동
# 2) 15>30 -> 오른쪽으로 이동
# 3) 30>28 -> 오른쪽으로 이동 해서 30을 검색한다.

# %% [markdown]
# #5번
# ![5..jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #6번
# 1.![image.png](data:image/png;base64,...)

# %% [markdown]
# #7번
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #8번
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #9번
# 최대 높이: n
# 최소 높이: log(n)
