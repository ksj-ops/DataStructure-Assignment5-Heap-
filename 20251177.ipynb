# %% [markdown]
# <a href="https://colab.research.google.com/github/ksj-ops/DataStructure-Assignment5-Heap-/blob/main/20251177.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab 시작 페이지

# %%
# 3번
class Heap:
    def __init__(self, *args):
        if len(args) != 0:
            self.__A = args[0]
        else:
            self.__A = []

    def insert(self, x):
        self.__A.append(x)
        self.__percolateUp(len(self.__A)-1)

    def __percolateUp(self, i:int):
        parent = (i - 1) // 2
        if i > 0 and self.__A[i] > self.__A[parent]:
            self.__A[i], self.__A[parent] = self.__A[parent], self.__A[i]
            self.__percolateUp(parent)

    def deleteMax(self):
        if (not self.isEmpty()):
            max_val = self.__A[0]
            last_val = self.__A.pop()
            if not self.isEmpty():
                self.__A[0] = last_val
                self.__percolateDown(0)
            return max_val
        else:
            return None

    def __percolateDown(self, i:int):
        child = 2 * i + 1
        right = 2 * i + 2
        if (child <= len(self.__A)-1):
            if (right <= len(self.__A)-1 and self.__A[child] < self.__A[right]):
                child = right
            if self.__A[i] < self.__A[child]:
                self.__A[i], self.__A[child] = self.__A[child], self.__A[i]
                self.__percolateDown(child)

    def isEmpty(self) -> bool:
        return len(self.__A) == 0

raw_data = [
    ("안서영", 2004, 6, 21), ("위주은", 2001, 1, 12), ("강예은", 2004, 8, 23),
    ("김예준", 2003, 3, 30), ("엥흐툽신", 1985, 12, 5), ("김승현", 2003, 3, 11),
    ("오정현", 2004, 8, 16), ("정인선", 2005, 11, 24), ("원솔은", 2003, 7, 14),
    ("이채민", 2004, 7, 18), ("이채윤", 2005, 8, 21), ("구수진", 2005, 4, 8),
    ("권지영", 2003, 2, 5), ("김수민", 2006, 7, 9), ("김주영", 2006, 11, 20),
    ("김태연", 2006, 3, 22), ("김효린", 2006, 12, 16), ("서지윤", 2005, 9, 22),
    ("이승주", 2006, 3, 26), ("이시현", 2006, 12, 5), ("이예지", 2005, 1, 4),
    ("이유민", 2005, 7, 11), ("이윤서", 2006, 12, 27), ("이주은", 2006, 7, 5),
    ("이채영", 2006, 4, 18), ("장채은", 2005, 5, 8), ("정희원", 2006, 12, 21),
    ("조은서", 2005, 7, 19), ("진가연", 2005, 11, 12), ("최윤지", 2006, 8, 30),
    ("황다원", 2004, 10, 15), ("박다인", 2005, 11, 9), ("안예원", 2004, 7, 9),
    ("정서하", 2006, 7, 20), ("김우현", 2006, 9, 1), ("양시언", 2006, 4, 18),
    ("유가현", 2006, 8, 22), ("이하연", 2006, 9, 22), ("장예은", 2006, 3, 17),
    ("전은빈", 2006, 1, 17), ("정세희", 2004, 12, 7), ("이예은", 2006, 12, 9)
]


heap = Heap()
for name, year, month, day in raw_data:
    # 비교 우선순위: 년 -> 월 -> 일 -> 이름
    heap.insert((year, month, day, name))


print("생일이 느린 순서(최신순) TOP 10 친구들 ")
print("-" * 40)
print(f"{'순위':<4} {'이름':<8} {'생년월일':<15}")
print("-" * 40)

count = 1
while not heap.isEmpty() and count <= 10:
    year, month, day, name = heap.deleteMax()
    print(f"{count:<4} {name:<8} {year:4}년 {month:2}월 {day:2}일")
    count += 1
# Out:
# 생일이 느린 순서(최신순) TOP 10 친구들
# ----------------------------------------
# 순위   이름       생년월일
# ----------------------------------------
# 1    이윤서      2006년 12월 27일
# 2    정희원      2006년 12월 21일
# 3    김효린      2006년 12월 16일
# 4    이예은      2006년 12월  9일
# 5    이시현      2006년 12월  5일
# 6    김주영      2006년 11월 20일
# 7    이하연      2006년  9월 22일
# 8    김우현      2006년  9월  1일
# 9    최윤지      2006년  8월 30일
# 10   유가현      2006년  8월 22일

# %%
#4번
class BidirectNode:
    def __init__(self, item, prev, next):
        self.item = item
        self.prev = prev
        self.next = next

class CircularDoublyLinkedList:
    def __init__(self):
        self.__head = BidirectNode("dummy", None, None)
        self.__head.prev = self.__head
        self.__head.next = self.__head
        self.__numItems = 0

    def append(self, newItem) -> None:
        prev = self.__head.prev
        newNode = BidirectNode(newItem, prev, self.__head)
        prev.next = newNode
        self.__head.prev = newNode
        self.__numItems += 1

    def getNode(self, i: int) -> BidirectNode:
        curr = self.__head
        for index in range(i + 1):
            curr = curr.next
        return curr

    def __iter__(self):
        return CircularDoublyLinkedListIterator(self)

class CircularDoublyLinkedListIterator:
    def __init__(self, alist):
        self.__head = alist.getNode(-1)
        self.iterPosition = self.__head.next
    def __next__(self):
        if self.iterPosition == self.__head:
            raise StopIteration
        else:
            item = self.iterPosition.item
            self.iterPosition = self.iterPosition.next
            return item


all_data = [
    ("안서영", 2004, 6, 21), ("위주은", 2001, 1, 12), ("강예은", 2004, 8, 23),
    ("김예준", 2003, 3, 30), ("엥흐툽신", 1985, 12, 5), ("김승현", 2003, 3, 11),
    ("오정현", 2004, 8, 16), ("정인선", 2005, 11, 24), ("원솔은", 2003, 7, 14),
    ("이채민", 2004, 7, 18), ("이채윤", 2005, 8, 21), ("구수진", 2005, 4, 8),
    ("권지영", 2003, 2, 5), ("김수민", 2006, 7, 9), ("김주영", 2006, 11, 20),
    ("김태연", 2006, 3, 22), ("김효린", 2006, 12, 16), ("서지윤", 2005, 9, 22),
    ("유지민", None, None, None), ("이승주", 2006, 3, 26), ("이시현", 2006, 12, 5),
    ("이예지", 2005, 1, 4), ("이유민", 2005, 7, 11), ("이윤서", 2006, 12, 27),
    ("이주은", 2006, 7, 5), ("이채영", 2006, 4, 18), ("장채은", 2005, 5, 8),
    ("정희원", 2006, 12, 21), ("조은서", 2005, 7, 19), ("진가연", 2005, 11, 12),
    ("최윤지", 2006, 8, 30), ("황다원", 2004, 10, 15), ("박다인", 2005, 11, 9),
    ("안예원", 2004, 7, 9), ("정서하", 2006, 7, 20), ("김우현", 2006, 9, 1),
    ("양시언", 2006, 4, 18), ("유가현", 2006, 8, 22), ("이하연", 2006, 9, 22),
    ("장예은", 2006, 3, 17), ("전은빈", 2006, 11, 7), ("정세희", 2004, 12, 7),
    ("이예은", 2006, 12, 9)
]


my_group_names = ["이채윤", "구수진", "권지영", "김수민", "김주영", "김태연", "김효린", "서지윤", "유지민", "이승주"]


linked_list = CircularDoublyLinkedList()
for data in all_data:
    linked_list.append(data)


print(f"{'이름':<8} | {'생년월일'}")
print("-" * 30)

for item in linked_list:
    name, year, month, day = item


    if name in my_group_names:
        if year is None or month is None or day is None:
            birth_str = "생일 정보 없음"
        else:
            birth_str = f"{year}년 {month}월 {day}일"

        print(f"{name:<8} | {birth_str}")
# Out:
# 이름       | 생년월일
# ------------------------------
# 이채윤      | 2005년 8월 21일
# 구수진      | 2005년 4월 8일
# 권지영      | 2003년 2월 5일
# 김수민      | 2006년 7월 9일
# 김주영      | 2006년 11월 20일
# 김태연      | 2006년 3월 22일
# 김효린      | 2006년 12월 16일
# 서지윤      | 2005년 9월 22일
# 유지민      | 생일 정보 없음
# 이승주      | 2006년 3월 26일

# %% [markdown]
# #5번
#
# #5-1
# A. 더 작은 값을 가질 수 없다
#
# #5-2
# A.마지막 원소인 A[n-1]이 항상 가장 작은 값을 가지는 것은 아니다.
#
# #5-3
# 그냥 넘어가는 원소의 수는 정확하게 절반이다.
#
# #5-4
# 최악의 경우: Θ(logn)
# 최선의 경우: Θ(1)
#
# #5-5
# 매우 간단한일이다.
#
# #5-6
# buildHeap()보다 비효율적이다.
# '위쪽에서부터 시작해서 스며오르기를 반복' 하는 것은 Θ(nlogn)이기 때문이다.
#
# #5-7
# 늘어난 그의 부모부터 heapify하면서 올라가는 과정을 거친다.
